# %%
import pandas as pd

csv3 = pd.read_csv('./data/clase_3.csv', sep=';')

csv4 = pd.read_csv('./data/clase_4.csv', sep=';')

csv_DS = pd.concat([csv3, csv4], ignore_index=True)

csv_DS = csv_DS.reset_index()
csv_DS['index'] = csv_DS['index'] +1
csv_DS = csv_DS.rename(columns={'index': 'IdAlumno'})

alumnos_DS = csv_DS[['IdAlumno','Nombre','Email']]



# Para sacar los nombres en un array en vez de un DF 
nombres = alumnos_DS['Nombre'].to_numpy()

alumnos_DS
# Out:
#     IdAlumno               Nombre                          Email
# 0          1       Amor Larrañaga       Amor_Larrañaga@gmail.com
# 1          2     Teodoro Alberola     Teodoro_Alberola@gmail.com
# 2          3          Cleto Plana          Cleto_Plana@gmail.com
# 3          4     Aitana Sebastián     Aitana_Sebastián@gmail.com
# 4          5     Dolores Valbuena     Dolores_Valbuena@gmail.com
# 5          6         Julie Ferrer         Julie_Ferrer@gmail.com
# 6          7       Mireia Cabañas       Mireia_Cabañas@gmail.com
# 7          8        Flavia Amador        Flavia_Amador@gmail.com
# 8          9        Albino Macias        Albino_Macias@gmail.com
# 9         10        Ester Sánchez        Ester_Sánchez@gmail.com
# 10        11   Luis Miguel Galvez   Luis_Miguel_Galvez@gmail.com
# 11        12       Loida Arellano       Loida_Arellano@gmail.com
# 12        13       Heraclio Duque       Heraclio_Duque@gmail.com
# ...

# %%
nombres
# Out:
# array(['Amor Larrañaga', 'Teodoro Alberola', 'Cleto Plana',
#        'Aitana Sebastián', 'Dolores Valbuena', 'Julie Ferrer',
#        'Mireia Cabañas', 'Flavia Amador', 'Albino Macias',
#        'Ester Sánchez', 'Luis Miguel Galvez', 'Loida Arellano',
#        'Heraclio Duque', 'Herberto Figueras', 'Teresa Laguna',
#        'Estrella Murillo', 'Ernesto Uriarte', 'Daniela Guitart',
#        'Timoteo Trillo', 'Ricarda Tovar', 'Alejandra Vilaplana',
#        'Daniel Rosselló', 'Rita Olivares', 'Cleto Montes',
#        'Marino Castilla', 'Estefanía Valcárcel', 'Noemí Vilanova'],
#       dtype=object)
